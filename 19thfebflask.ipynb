# %%
print("\n\n19 th feb flask\n\n")
q1 ="Q1. What is Flask Framework? What are the advantages of Flask Framework?\n"
print(q1)
ans1="""\nFlask is a web framework, it’s a Python module that lets you develop web applications 
easily. It’s has a small and easy-to-extend core: it’s a microframework that doesn’t include an 
ORM (Object Relational Manager) or such features.

advantage of flask framework
It does have many cool features like url routing, template engine. It is a WSGI web app framework
\n"""
print(ans1)
# Out:
# 19 th feb flask
#
#
# Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
#
# Flask is a web framework, it’s a Python module that lets you develop web applications
# easily. It’s has a small and easy-to-extend core: it’s a microframework that doesn’t include an
# ORM (Object Relational Manager) or such features.
#
# advantage of flask framework
# It does have many cool features like url routing, template engine. It is a WSGI web app framework

# %%
q2 ='''\n\nQ2. Create a simple Flask application to display ‘Hello World!!’. Attach the 
screenshot of the output in Jupyter Notebook.\n\n'''
print(q2)
ans2="""from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello, World!</h1>"


if __name__=="__main__":
    app.run(host="0.0.0.0")"""
print(ans2)
from PIL import Image

img = Image.open("helloworld.png")
img
# Out:
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the
# screenshot of the output in Jupyter Notebook.
#
#
# from flask import Flask
#
# app = Flask(__name__)
#
# @app.route("/")
# def hello_world():
#     return "<h1>Hello, World!</h1>"
#
#
# if __name__=="__main__":
#     app.run(host="0.0.0.0")
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %%
q3 ="\nQ3. What is App routing in Flask? Why do we use app routes?\n"
print(q3)
ans3 ='''App Routing means mapping the URLs to a specific function that will handle the logic for
that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make
navigation simpler. '''
print(ans3)
# Out:
# Q3. What is App routing in Flask? Why do we use app routes?
#
# App Routing means mapping the URLs to a specific function that will handle the logic for
# that URL. Modern web frameworks use more meaningful URLs to help users remember the URLs and make
# navigation simpler.

# %%
q4='''Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and
a “/” route to show the following details:
Company Name: ABC Corporation
Location: India
Contact Detail: 999-999-9999'''
from PIL import Image



image =Image.open("welcome.png")
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %%
from PIL import Image

img = Image.open("abc.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %%
q5 ="""\nQ5. What function is used in Flask for URL Building? Write a Python code to demonstrate 
the working of the url_for() function.\n"""
print(q5)
ans5 ='''The url_for() function is used to build a URL to the specific function dynamically. The
first argument is the name of the specified function, and then we can pass any number of keyword
argument corresponding to the variable part of the URL.
This function is useful in the sense that we can avoid hard-coding the URLs into the templates by
dynamically building them using this function.
Consider the following python flask script'''
print(ans5)
# Out:
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate
# the working of the url_for() function.
#
# The url_for() function is used to build a URL to the specific function dynamically. The
# first argument is the name of the specified function, and then we can pass any number of keyword
# argument corresponding to the variable part of the URL.
# This function is useful in the sense that we can avoid hard-coding the URLs into the templates by
# dynamically building them using this function.
# Consider the following python flask script
