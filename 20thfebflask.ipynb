# %%
print("19th feb flask")
q1="\nQ1. Explain GET and POST methods.\n"
print(q1)
ans1 ="""GET is used to request data from a specified resource.
Note that the query string (name/value pairs) is sent in the URL of a GET request:

eg. /test/demo_form.php?name1=value1&name2=value2

POST is used to send data to a server to create/update a resource.
The data sent to the server with POST is stored in the request body of the HTTP request"""
print(ans1)
# Out:
# 19th feb flask
#
# Q1. Explain GET and POST methods.
#
# GET is used to request data from a specified resource.
# Note that the query string (name/value pairs) is sent in the URL of a GET request:
#
# eg. /test/demo_form.php?name1=value1&name2=value2
#
# POST is used to send data to a server to create/update a resource.
# The data sent to the server with POST is stored in the request body of the HTTP request

# %%
q2="\nQ2. Why is request used in Flask?\n"
print(q2)
ans2="""In the client-server architecture, the request object contains all the data that is sent
from the client to the server.we can retrieve the data at the server side using the HTTP method
The Request, in Flask, is an object that contains all the data sent from the Client to Server.
This data can be recovered using the GET/POST Methods"""
print(ans2)
# Out:
# Q2. Why is request used in Flask?
#
# In the client-server architecture, the request object contains all the data that is sent
# from the client to the server.we can retrieve the data at the server side using the HTTP method
# The Request, in Flask, is an object that contains all the data sent from the Client to Server.
# This data can be recovered using the GET/POST Methods

# %%
q3="\nQ3. Why is redirect() used in Flask?\n"
print(q3)
ans3="""Flask redirect is defined as a function or utility in Flask which allows developers to 
redirect users to a specified URL and assign a specified status code. When this function is 
called, a response object is returned, and the redirection happens to the target location with 
the status code."""
print(ans3)
# Out:
# Q3. Why is redirect() used in Flask?
#
# Flask redirect is defined as a function or utility in Flask which allows developers to
# redirect users to a specified URL and assign a specified status code. When this function is
# called, a response object is returned, and the redirection happens to the target location with
# the status code.

# %%
q4 ="\nQ4. What are templates in Flask? Why is the render_template() function used?\n"
print(q4)
ans4="""we have returned the simple string as the response from the view function. Although,
flask facilitates us to return the response in the form of HTML templates
render_template is a Flask function from the flask. templating package. render_template is used
to generate output from a template file based on the Jinja2 engine that is found in the
application's templates folder"""
print(ans4)
# Out:
# Q4. What are templates in Flask? Why is the render_template() function used?
#
# we have returned the simple string as the response from the view function. Although,
# flask facilitates us to return the response in the form of HTML templates
# render_template is a Flask function from the flask. templating package. render_template is used
# to generate output from a template file based on the Jinja2 engine that is found in the
# application's templates folder

# %%
q5 ="""\nQ5.Create a simple API. Use Postman to test it. Attach the screenshot of the output in 
the Jupyter Notebook.\n"""
print(q5)
from PIL import Image
img =Image.open("postman.png")
img
# Out:
# Q5.Create a simple API. Use Postman to test it. Attach the screenshot of the output in
# the Jupyter Notebook.
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>
